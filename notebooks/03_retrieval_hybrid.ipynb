# %%
import os, psycopg, sys, numpy as np

sys.path.append(r"C:\Git projects\sales_marketing_rag")
                
from app.rag import retrieve
for q in ["What did management say about marketing spend last quarter?",
          "Which customer segments drove revenue growth?",
          "How does the company describe its competitive positioning?"]:
    print("Q:", q)
    for r in retrieve(q): print("  -", r["content"][:160].replace("\n"," "), "…")
    print()
# Out:
# Q: What did management say about marketing spend last quarter?
#   - For the past 8 years, we have been the leaders in customer value creation for our industry. Overall, greater focus across each element of the fees resulted in b …
#   - So it’s very — it’s the first time that I can remember going back, gosh, many quarters, to have 3 of those types of effects hitting us in the same quarter. So i …
#   - And it’s important for us to feel good about whatever outcome happens either on that or in other areas, that we have what we need to deal with it. So ’26, very  …
#   - Operator: Our last question today will come from Robert Moskow from TD Cowen. Robert Moskow: You might have touched on this, but I was wondering about the mix h …
#   - Robert Moskow: Hi. Thank you for the question. John, I just wanted to get a sense of your level of conviction that concentrate volume returns to positive territ …
# ...
